# %% [markdown]
# ## 1. Initialize the project
#
# Create the working context: data download project if not created already. Project is a placeholder for the code, data, and management of the data operations.

# %%
import digitalhub as dh
PROJECT_NAME = "<YOUR_PROJECT_NAME>"
proj = dh.get_or_create_project(PROJECT_NAME)

# %% [markdown]
# Note: Make sure to replace <YOUR_PROJECT_NAME> with the actual name of your project before running the code.

# %% [markdown]
# ## 3. Execution

# %% [markdown]
# Fetch the "example-container-serve" operation in the project.

# %%
function = proj.get_function("example-container-serve")

# %% [markdown]
# Alternatively, one can create new function

# %%
function = proj.new_function(
    kind="container",
    name="my_container_function_serve",
    image="hashicorp/http-echo:latest",
)

# %% [markdown]
# We can now run the function and see the results. To do this we use the run method of the function.

# %%
run = function.run(
    action="serve",
    replicas=2,
    service_ports=[{"port": 5678, "target_port": 5678}],
    service_name="http-echo",
    run_as_user="8877",
    wait=True,
)

# %% [markdown]
# Note: Wait for job to finish. Alternatively, using the Core Management UI, one can navigate to 'Runs' menu , select the corresponding 'run' instance and inspect the logs using 'Logs' tab.

# %% [markdown]
# To invoke the deployed service, use the `invoke()` method on the run object. This sends a request to the running container and returns the response. You can inspect the output by printing the response text.

# %%
response = run.invoke()
print(response.text)

# %%
hello-world
